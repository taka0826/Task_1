# %%
# !pip install numpy
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/shimizutakahiro/.pyenv/versions/3.8.5/bin/python3.8 -m pip install --upgrade pip' command.

# %%
print(np.array[1,2,3,3,2,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/q9/_khqm_ns7y120j_lzxbxdp880000gn/T/ipykernel_89472/2256070502.py in <module>
# ----> 1 print(np.array[1,2,3,3,2,1])
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
# !pip install requests
# Out:
# ...
#      |████████████████████████████████| 62 kB 669 kB/s
# ...
#      |████████████████████████████████| 59 kB 1.9 MB/s
# ...
#      |████████████████████████████████| 138 kB 2.4 MB/s
# ...
#   Using cached certifi-2021.5.30-py2.py3-none-any.whl (145 kB)
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/shimizutakahiro/.pyenv/versions/3.8.5/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import requests
import zipfile
import io
import os
import numpy as np
import numpy.random as random
import scipy as sp
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline
# %precision 3
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# データがあるurlの指定
url = "https://katolab2020.slack.com/files/URPMSR1FB/F02953PF0M9/cal_result.csv"
# データをurlから取得
r = requests.get(url, stream=True)
cal_result_info = pd.read_csv("cal_result.csv", sep=";")
cal_result_info.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/q9/_khqm_ns7y120j_lzxbxdp880000gn/T/ipykernel_89472/1364294834.py in <module>
#       5 import numpy as np
#       6 import numpy.random as random
# ----> 7 import scipy as sp
#       8 import pandas as pd
#       9 from pandas import Series, DataFrame
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# !pip install pandas
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the '/Users/shimizutakahiro/.pyenv/versions/3.8.5/bin/python3.8 -m pip install --upgrade pip' command.

# %%
# !pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 7.2 MB 1.9 MB/s
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached kiwisolver-1.3.1-cp38-cp38-macosx_10_9_x86_64.whl (61 kB)
# ...
#      |████████████████████████████████| 2.9 MB 2.4 MB/s
# ...
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# ...

# %%
# !pip install seaborn
# Out:
# ...
#      |████████████████████████████████| 292 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 32.6 MB 510 kB/s
# ...

# %%
import pandas as pd

info_1 = pd.read_csv("/Users/shimizutakahiro/katolab-code/Task_1/cal_result.csv")
info_2 = pd.read_csv("/Users/shimizutakahiro/katolab-code/Task_1/ex_result.csv")

info_1
# Out:
#            #         a         b         c
# 0     Vase12  0.097894  7.266003  0.001072
# 1     Vase13  0.168052  2.880366  0.004643
# 2     Vase11  0.147100  3.672491  0.003187
# 3     Vase10  0.400081  2.407038  0.013227
# 4     Vase14  0.266584  2.529097  0.008388
# 5       Vase  0.266584  2.529097  0.008388
# 6     Vase17  0.323093  2.618346  0.009820
# 7     Vase16  0.210427  2.482751  0.006745
# 8      Vase5  0.137582  2.863075  0.003824
# 9      Vase4  0.339742  2.428207  0.011134
# 10     Vase6  0.298062  3.285638  0.007219
# 11     Vase7  0.147930  3.355923  0.003508
# 12     Vase3  0.183017  2.746347  0.005303
# 13     Vase2  0.194927  3.982347  0.003895
# 14     Vase1  0.121123  3.373518  0.002857
# 15  Vase20-1  0.216503  2.593335  0.006643
# 16     Vase9  0.196978  2.855756  0.005489
# 17     Vase8  0.211503  2.818170  0.005972
# 18    Vase18  0.185235  3.989348  0.003695
# 19    Vase19  0.182960  3.165010  0.004600
# 20    Vase25  0.209932  3.393869  0.004922
# ...

# %%
info_2
# Out:
#            #   complex     order  preference
# 0       Vase  3.333333  2.960000    2.693333
# 1      Vase1  2.386667  3.973333    3.400000
# 2     Vase10  4.480000  2.133333    2.133333
# 3     Vase11  2.973333  3.080000    2.800000
# 4     Vase12  2.346667  3.893333    2.746667
# 5     Vase13  3.546667  3.653333    3.146667
# 6     Vase14  3.200000  2.933333    2.733333
# 7     Vase16  3.573333  2.800000    2.613333
# 8     Vase17  3.066667  3.120000    2.693333
# 9     Vase18  2.346667  3.640000    2.986667
# 10    Vase19  2.333333  3.906667    3.066667
# 11     Vase2  2.773333  3.733333    2.973333
# 12    Vase20  3.773333  3.173333    2.626667
# 13  Vase20-1  3.653333  3.373333    2.986667
# 14    Vase21  3.053333  3.813333    3.426667
# 15    Vase22  3.933333  2.266667    2.306667
# 16    Vase23  3.200000  3.200000    2.720000
# 17    Vase25  2.853333  3.786667    3.413333
# 18     Vase3  4.000000  2.613333    2.800000
# 19     Vase4  3.786667  2.400000    2.440000
# ...

# %%
# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()

# jupiter notebookでグラフを表示する
# %matplotlib inline
# 小数第３位まで表示
# %precision 3

# 散布図を作る
import numpy.random as random
#　シード値の固定
random.seed(0)

# x軸のデータ
x = info_1.b
# y軸のデータ
y = info_2.complex
# グラフの大きさ指定
plt.figure(figsize=(15, 5))
# グラフの描写
plt.plot(x,y, "o")

# 相関係数
rr = np.corrcoef(x,y)[0,1]
# タイトル
plt.title("Task1:" + str(rr))
# Xの座標名
plt.xlabel('score_b')
# Yの座標名
plt.ylabel('complex')

# grid（グラフの中にある縦線と横線）の表示
plt.grid(True)

# %%
np.corrcoef(x,y)[0,1]
# Out:
# 0.2068702308847543
